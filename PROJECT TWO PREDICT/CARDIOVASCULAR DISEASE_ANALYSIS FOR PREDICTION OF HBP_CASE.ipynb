# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# read the data
df_data = pd.read_csv('heart_failure_clinical_records_dataset-pcp.csv')

# %%
df_data.head(4)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  gender  \
# 0                    1  265000.00               1.9           130       1
# 1                    0  263358.03               1.1           136       1
# 2                    0  162000.00               1.3           129       1
# 3                    0  210000.00               1.9           137       1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1

# %%
df_data.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'gender', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   gender                    299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
# checking the statistics of the data
df_data.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
# HBP = High blood pressure

# %% [markdown]
# ### VISUALIZATION

# %%
class visualization:
    def __init__(self, df_data):
        self.df_data = df_data
    
    def missing_value(self): # check for missing value
        sns.heatmap(self.df_data.isnull(), yticklabels = False, cbar =False, cmap = 'Blues')
        
    def distribution(self): # checking the distribution of the variable
        self.df_data.hist(bins = 30, figsize = (20,20), color = 'b')
        
    def age_distribution_death_case(self): # checking age distribution
        plt.figure(figsize = [25,12])
        sns.countplot(x = 'age', hue = 'high_blood_pressure', data = self.df_data)
        
    def gender_High_blood_pressure(self):# checking gender on HBP
        plt.figure(figsize = [15,30])
        plt.subplot(411)
        sns.countplot(x = 'gender', hue = 'high_blood_pressure', data = self.df_data)

    def anaemia_High_blood_pressure_plot(self):# checking if there is effect of anaemia on HBP
        plt.figure(figsize = [15,30])
        plt.subplot(412)
        sns.countplot(x = 'anaemia', hue = 'high_blood_pressure', data = self.df_data)

    def diabetes_High_blood_pressure_plot(self):# checking if there is effect of diabetes on HBP
        plt.figure(figsize = [15,30])
        plt.subplot(413)
        sns.countplot(x = 'diabetes', hue = 'high_blood_pressure', data = self.df_data)

    def smoking_HBP_plot(self):# checking if there is effect of smoking on HBP
        plt.figure(figsize = [15,30])
        plt.subplot(414)
        sns.countplot(x = 'smoking', hue = 'high_blood_pressure', data = self.df_data)
   
    def distribution_plot_High_blood_pressure(self):# checking possible pattern for predicting HBP
        sns.pairplot(df_data, hue = 'high_blood_pressure')


visual_plot = visualization(df_data)

# %%
# Check for missing value
visual_plot. missing_value()

# %%
# this indicate there is no missing value in the data

# %%
# Checkingthe distribution of the data
visual_plot. distribution()

# %%
# the chart shows the distribution of each variable to be use for building the model

# %%
# How many person die
HBP_df = df_data[df_data['high_blood_pressure'] == 1]
no_HBP_df = df_data[df_data['high_blood_pressure'] == 0]

# %%
print('Total = ', len(df_data))
print('Number of person that have anaemia = ', len(HBP_df))
print('% of person that have anaemia =',1.*len(HBP_df)/len(df_data)*100, '%')


print("Number of person that don't have anaemia = ", len(no_HBP_df))
print("% of person that don't have anaemia =", 1.*len(no_HBP_df)/len(df_data)*100, '%')
# Out:
# Total =  299
# Number of person that have anaemia =  105
# % of person that have anaemia = 35.11705685618729 %
# Number of person that don't have anaemia =  194
# % of person that don't have anaemia = 64.88294314381271 %

# %%
# this help to see the differece in the number of people with anaemia and without
# it also shows if the data to be used is balanced or not
# it is seen that there is differece between 35% of those with anaemia and 65% without anaemia

# %%
# checking for patterns
visual_plot.distribution_plot_High_blood_pressure()

# %%
# The chart analysis  Assess whether there are patterns or trends that differentiate the 
# high blood pressure category

# %%
HBP_df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  105.000000  105.000000                105.000000  105.000000
# mean    62.339686    0.457143                488.895238    0.409524
# std     11.516151    0.500549                869.425439    0.494104
# min     40.000000    0.000000                 30.000000    0.000000
# 25%     53.000000    0.000000                113.000000    0.000000
# 50%     62.000000    0.000000                220.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7702.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         105.000000                105.0     105.000000
# mean           38.476190                  1.0  269989.183238
# std            12.422912                  0.0   84594.105191
# min            17.000000                  1.0  126000.000000
# ...

# %%
no_HBP_df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  194.000000  194.000000                194.000000  194.000000
# mean    60.018902    0.417526                632.144330    0.422680
# std     12.045547    0.494427               1019.354169    0.495264
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     50.000000    0.000000                123.750000    0.000000
# 50%     60.000000    0.000000                275.500000    0.000000
# 75%     66.500000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         194.000000                194.0     194.000000
# mean           37.871134                  0.0  259769.002629
# std            11.531390                  0.0  104291.648566
# min            14.000000                  0.0   25100.000000
# ...

# %% [markdown]
# ## Comparing the population that have high blood pressure and those don't have
# **'Age':** The average age of the population that have anaemia is slightly higher than those that don't have
#
# **'creatinine_phosphokinase' :** Average creatinine_phosphokinase of those with anaemia is less than those that don't have
#
# **'diabetes' :** Average Percentage of the sample population that don't have anaemia is slightly higher than those that have
#
# **'ejection_fraction' :** Average number of the sample population that have anaemia is slightly higher than those that have
#
# **'high_blood_pressure' :** Average Percentage of the sample population that have anaemia,have higher high blood pressure
#
# **'smoking' :** Average proportion of the sample population that have anaemia don't smoke compare to those that don't have
#
# **'Time' :** Average time of the sample population that have anaemia are lower than those that don't have

# %% [markdown]
# ## Correlation

# %%
correlation = df_data.corr()
f, ax = plt.subplots(figsize = (12,10))
sns.heatmap(correlation, annot = True)
# Out:
# <AxesSubplot:>

# %%
# the correlation chart shows that for every negative value correlation with high blood pressure, the chance of having 
# high blood pressure reduce and for positive correlation with high blood pressure, the higher the chance of having anaemia but 
# magnitude of the correlation value determine the weight of the impact

# %%
# checking the relationship of the age against two groups

visual_plot.age_distribution_death_case()

# %%
# This shows that one can have high blood pressure based on the age group display above because those that have it are 
# spread across all age group but more consistent from age 44

# %%
df_data.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'gender', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
visual_plot.gender_High_blood_pressure()

# %%
# For the gender, both group have significant number of case of high blood pressure

# %%
visual_plot.anaemia_High_blood_pressure_plot()

# %%
# For the population with anaemia, both group have significant number of case of high blood pressure

# %%
visual_plot.diabetes_High_blood_pressure_plot()

# %%
# For the population with diabetes, both group have significant number of case of high blood pressure

# %%
visual_plot.smoking_HBP_plot()

# %%
# For the population with smoking, both group have significant number of case of high blood pressure

# %%
# plot to compare

# %%
class KDEPlotter:
    def __init__(self, HBP_df, no_HBP_df):
        self.HBP_df = HBP_df
        self.no_HBP_df = no_HBP_df
    
    def kdeplot_time(self):
        plt.figure(figsize = (10,7))
        sns.kdeplot(self.HBP_df['time'], label = 'Population that have HBP', shade = True, color ='r')
        sns.kdeplot(self.no_HBP_df['time'], label = "Population that don't have HBP", shade = True, color ='b')

        plt.xlabel('Heart Failure Time Taken ')
        plt.legend()
        plt.show()

    def kdeplot_creatinine_phosphokinase(self):
        plt.figure(figsize = (10,7))
        sns.kdeplot(self.HBP_df['creatinine_phosphokinase'], label = 'Population that have HBP', shade = True, color ='r')
        sns.kdeplot(self.no_HBP_df['creatinine_phosphokinase'], label = "Population that don't have HBP", shade = True, color ='b')

        plt.xlabel('creatinine phosphokinase rate ')
        plt.legend()
        plt.show()

    def kdeplot_ejection_fraction(self):
        plt.figure(figsize = (10,7))
        sns.kdeplot(self.HBP_df['ejection_fraction'], label = "Population that have HBP", shade = True, color ='r')
        sns.kdeplot(self.no_HBP_df['ejection_fraction'], label = "Population that don't have HBP", shade = True, color ='b')

        plt.xlabel('ejection fraction rate ')
        plt.legend()
        plt.show()

    def kdeplot_platelets(self):
        plt.figure(figsize = (10,7))
        sns.kdeplot(self.HBP_df['platelets'], label = "Population that have HBP", shade = True, color ='r')
        sns.kdeplot(self.no_HBP_df['platelets'], label = "Population that don't have HBP", shade = True, color ='b')

        plt.xlabel('platelets rate ')
        plt.legend()
        plt.show()


    def kdeplot_serum_creatinine(self):    
        plt.figure(figsize = (10,7))
        sns.kdeplot(self.HBP_df['serum_creatinine'], label = "Population that have HBP", shade = True, color ='r')
        sns.kdeplot(self.no_HBP_df['serum_creatinine'], label = "Population that don't have HBP", shade = True, color ='b')

        plt.xlabel('serum creatinine rate ')
        plt.legend()
        plt.show()


    def kdeplot_serum_sodium(self):    
        plt.figure(figsize = (10,7))
        sns.kdeplot(self.HBP_df['serum_sodium'], label = "Population that have HBP", shade = True, color ='r')
        sns.kdeplot(no_HBP_df['serum_sodium'], label = "Population that don't have HBP", shade = True, color ='b')

        plt.xlabel('serum_sodium rate ')
        plt.legend()
        plt.show()

kde_plotter = KDEPlotter(HBP_df, no_HBP_df)

# %%
kde_plotter.kdeplot_time()

# %%
# Those with high blood pressure have population density concentrated at 0.005 at around  0 to 100 heart failure rate and also 
# another peak between 0.003 and 0.004 at heart failure rate of 200

# Those without high blood pressure have population density concentrated at 0.004 heart failure rate of 100
# and also another peak between 0.003 and 0.004 at heart failure rate between 200 and 300

# %%
kde_plotter.kdeplot_creatinine_phosphokinase()

# %%
# Those with high blood pressure have population density concentrated at 0.0008 at around  0 to 500 creatinine phosphokinase 
# rate and fewer population at larger creatinine phosphokinase rate

# Those without high blood pressure have population density concentrated at almost 0.0008 at around  0 to 500 creatinine 
# phosphokinase rate and fewer population at larger creatinine phosphokinase rate

# %%
kde_plotter.kdeplot_ejection_fraction()

# %%
# Those that don't have high blood pressure have higher concentration of ejection fraction rate at 40 and population density at
# 0.040 above

# Those that don't have high blood pressure have higher concentration of ejection fraction rate at 40 and population density at
# 0.032

# %%
kde_plotter.kdeplot_platelets()

# %%
# the two population group have almost same density of 5 at platelets rate interval of 
# between 0.2 and 0.3

# the two have almost same class interval with fewer groups around the lower boundary and 
# the upper boundry

# %%
kde_plotter.kdeplot_serum_creatinine()

# %%
# The two population group have a concentration rate of population between serum creatinine rate of between 0 and 2

# both group have fewer higher value to the right

# the population with high blood pressure have density concentration (population) of 0.6

# the population that don't have high blood pressure have density concentration (population) of 0.8

# %%
kde_plotter.kdeplot_serum_sodium()

# %%
# The two population group have a high density population between serum creatinine rate of between 130 and 145

# both group have fewer lower value to the left of the class boundry

# %%
#pip install imbalanced-learn

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

from imblearn.under_sampling import TomekLinks
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler

import warnings
warnings.filterwarnings("ignore")

# %%
df_data.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'gender', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
# we drop death because it is the final stage of life and cannot be use to predict High blood pressure

df_data = df_data[['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
       'ejection_fraction', 'high_blood_pressure', 'platelets',
       'serum_creatinine', 'serum_sodium', 'gender', 'smoking', 'time']]

# %%
df_data.head(2)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  gender  \
# 0                    1  265000.00               1.9           130       1
# 1                    0  263358.03               1.1           136       1
#
#    smoking  time
# 0        0     4
# 1        0     6

# %%
y = df_data['high_blood_pressure']
X = df_data.drop(labels=['high_blood_pressure'], axis=1)

# %% [markdown]
# ### Separate dataset into train and test

# %%
# separate dataset into train and test

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.3,
                                                    random_state = 0)
X_train.shape, X_test.shape
# Out:
# ((209, 11), (90, 11))

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
# Data Normalisation and Data scaling
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
# set up Tomek Links

tl = TomekLinks(
    sampling_strategy='auto',  # undersamples only the majority class
    n_jobs=4)  

X_resampled_t, y_resampled_t = tl.fit_resample(X_train, y_train)

# %%
X_resampled_t.shape, y_resampled_t.shape
# Out:
# ((184, 11), (184,))

# %%
# set up Border line SMOTE

sm_bl = BorderlineSMOTE(
    sampling_strategy='auto',  # samples only the minority class
    random_state=0,  # for reproducibility
    k_neighbors=5, # the neighbours to crete the new examples
    m_neighbors=10, # the neiighbours to find the DANGER group
    kind='borderline-1',
    n_jobs=4
)

X_resampled_b, y_resampled_b = sm_bl.fit_resample(X_train, y_train)

# %%
X_resampled_b.shape, y_resampled_b.shape
# Out:
# ((268, 11), (268,))

# %%
# set up SMOTE

sm = SMOTE(
    sampling_strategy='auto',  # samples only the minority class
    random_state=0,  # for reproducibility
    k_neighbors=5,
    n_jobs=4
)

X_resampled_s, y_resampled_s = sm.fit_resample(X_train, y_train)

# %%
X_resampled_b.shape, y_resampled_b.shape
# Out:
# ((268, 11), (268,))

# %%
# set up Random oversampler

ros = RandomOverSampler(
    sampling_strategy='not majority', # samples all but majority class
    random_state=0,  # for reproducibility
)  

X_resampled_ros, y_resampled_ros = ros.fit_resample(X_train, y_train)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.metrics import ConfusionMatrixDisplay,classification_report
from yellowbrick.classifier import (
    ClassificationReport,
    DiscriminationThreshold,
)

# %% [markdown]
# ### RANDOM FOREST MODEL

# %%
def run_randomForests(X_train, X_test, y_train, y_test):
    
    rf = RandomForestClassifier(random_state = 42)
    rf.fit(X_train, y_train)
    
    
    
    pred = rf.predict(X_test)
    
    
    sns.reset_orig()

    ConfusionMatrixDisplay.from_predictions(
            y_test, pred,
            labels = rf.classes_,
            cmap = 'magma'
    );
    
   
    print('Test')
    print(classification_report(y_test, pred, target_names = ['No High blood pressure', 'High blood pressure']))
    
    
    print('Train set')
    pred = rf.predict_proba(X_train)
    print('Random Forests roc-auc: {}'.format(roc_auc_score(y_train, pred[:,1])))
    
    print('Test set')
    pred = rf.predict_proba(X_test)
    print('Random Forests roc-auc: {}'.format(roc_auc_score(y_test, pred[:,1])))

# %% [markdown]
# ### Evaluate performance of algorithm built using imbalanced dataset

# %%
# evaluate performance of algorithm built using imbalanced dataset

run_randomForests(X_train,
                  X_test,
                  y_train,
                  y_test)
# Out:
# Test
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.70      0.83      0.76        60
#    High blood pressure       0.47      0.30      0.37        30
#
#               accuracy                           0.66        90
#              macro avg       0.59      0.57      0.57        90
#           weighted avg       0.63      0.66      0.63        90
#
# Train set
# Random Forests roc-auc: 1.0
# Test set
# Random Forests roc-auc: 0.576388888888889

# %% [markdown]
# ### Evaluate performance of algorithm built using Tomek Links

# %%
# evaluate performance of algorithm built using Tomek Links

run_randomForests(X_resampled_t,
                  X_test,
                  y_resampled_t,
                  y_test)
# Out:
# Test
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.70      0.72      0.71        60
#    High blood pressure       0.41      0.40      0.41        30
#
#               accuracy                           0.61        90
#              macro avg       0.56      0.56      0.56        90
#           weighted avg       0.61      0.61      0.61        90
#
# Train set
# Random Forests roc-auc: 1.0
# Test set
# Random Forests roc-auc: 0.5902777777777778

# %% [markdown]
# ### Evaluate performance of algorithm built using Border line SMOTE (Oversample method)

# %%
# evaluate performance of algorithm built using Border line SMOTE

run_randomForests(X_resampled_b,
                  X_test,
                  y_resampled_b,
                  y_test)
# Out:
# Test
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.71      0.60      0.65        60
#    High blood pressure       0.38      0.50      0.43        30
#
#               accuracy                           0.57        90
#              macro avg       0.55      0.55      0.54        90
#           weighted avg       0.60      0.57      0.58        90
#
# Train set
# Random Forests roc-auc: 1.0
# Test set
# Random Forests roc-auc: 0.5730555555555555

# %% [markdown]
# ### Evaluate performance of algorithm built using SMOTE

# %%
# evaluate performance of algorithm built using SMOTE

run_randomForests(X_resampled_s,
                  X_test,
                  y_resampled_s,
                  y_test)
# Out:
# Test
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.70      0.70      0.70        60
#    High blood pressure       0.40      0.40      0.40        30
#
#               accuracy                           0.60        90
#              macro avg       0.55      0.55      0.55        90
#           weighted avg       0.60      0.60      0.60        90
#
# Train set
# Random Forests roc-auc: 0.9999999999999999
# Test set
# Random Forests roc-auc: 0.5983333333333333

# %% [markdown]
# ### Evaluate performance of algorithm built using Random oversampler

# %%
# evaluate performance of algorithm built using Random oversampler

run_randomForests(X_resampled_ros,
                  X_test,
                  y_resampled_ros,
                  y_test)
# Out:
# Test
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.70      0.77      0.73        60
#    High blood pressure       0.42      0.33      0.37        30
#
#               accuracy                           0.62        90
#              macro avg       0.56      0.55      0.55        90
#           weighted avg       0.60      0.62      0.61        90
#
# Train set
# Random Forests roc-auc: 1.0
# Test set
# Random Forests roc-auc: 0.5666666666666667

# %% [markdown]
# ### IMPROVING THE MODEL USING Gridsearch FOR RANDOM FOREST MODEL

# %%
# Define the parameter grid
param_grid = {
    'n_estimators': [5,10, 20, 50,100, 200, 500],
    'max_depth': [None, 1, 2, 3, 4],
    'min_samples_split': [0.1, 0.3, 0.5, 1, 3 , 5]
}

# %%
def grid_randomForests(X_train, X_test, y_train, y_test):
    
    rf_classifier = RandomForestClassifier(random_state = 42)
    
    grid_search = GridSearchCV(rf_classifier, param_grid, cv=5)
    #grid_search.best_params_
    grid_search.fit(X_train, y_train)
    
    
    grid_predictions = grid_search.predict(X_test)
    
    sns.reset_orig()

    ConfusionMatrixDisplay.from_predictions(
            y_test, grid_predictions,
            labels = grid_search.classes_,
            cmap = 'magma'
    );
    
    
    
    print(classification_report(y_test, grid_predictions, target_names = ['No High blood pressure', 'High blood pressure']))
    
    
    print('Train set')
    grid_predictions = grid_search.predict_proba(X_train)
    print('Random Forests roc-auc: {}'.format(roc_auc_score(y_train, grid_predictions[:,1])))
    
    print('Test set')
    grid_predictions = grid_search.predict_proba(X_test)
    print('Random Forests roc-auc: {}'.format(roc_auc_score(y_test, grid_predictions[:,1])))

# %% [markdown]
# ### Evaluate performance of algorithm built using imbalanced dataset

# %%
# evaluate performance of algorithm built using imbalanced dataset

grid_randomForests(X_train,
                  X_test,
                  y_train,
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.67      1.00      0.80        60
#    High blood pressure       0.00      0.00      0.00        30
#
#               accuracy                           0.67        90
#              macro avg       0.33      0.50      0.40        90
#           weighted avg       0.44      0.67      0.53        90
#
# Train set
# Random Forests roc-auc: 0.6827363184079601
# Test set
# Random Forests roc-auc: 0.5416666666666667

# %% [markdown]
# ### Evaluate performance of algorithm built using Tomek Links

# %%
# evaluate performance of algorithm built using Tomek Links

grid_randomForests(X_resampled_t,
                  X_test,
                  y_resampled_t,
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.68      0.87      0.76        60
#    High blood pressure       0.38      0.17      0.23        30
#
#               accuracy                           0.63        90
#              macro avg       0.53      0.52      0.50        90
#           weighted avg       0.58      0.63      0.58        90
#
# Train set
# Random Forests roc-auc: 0.7194495412844036
# Test set
# Random Forests roc-auc: 0.5994444444444446

# %% [markdown]
# ### Evaluate performance of algorithm built using Border line SMOTE

# %%
grid_randomForests(X_resampled_b,
                  X_test,
                  y_resampled_b,
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.68      0.63      0.66        60
#    High blood pressure       0.35      0.40      0.38        30
#
#               accuracy                           0.56        90
#              macro avg       0.52      0.52      0.52        90
#           weighted avg       0.57      0.56      0.56        90
#
# Train set
# Random Forests roc-auc: 1.0
# Test set
# Random Forests roc-auc: 0.5761111111111111

# %% [markdown]
# ### Evaluate performance of algorithm built using SMOTE

# %%
# evaluate performance of algorithm built using SMOTE

grid_randomForests(X_resampled_s,
                  X_test,
                  y_resampled_s,
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.70      0.70      0.70        60
#    High blood pressure       0.40      0.40      0.40        30
#
#               accuracy                           0.60        90
#              macro avg       0.55      0.55      0.55        90
#           weighted avg       0.60      0.60      0.60        90
#
# Train set
# Random Forests roc-auc: 1.0
# Test set
# Random Forests roc-auc: 0.6111111111111112

# %% [markdown]
# ### Evaluate performance of algorithm built using Random oversampler

# %%
# evaluate performance of algorithm built using Random oversampler

grid_randomForests(X_resampled_ros,
                  X_test,
                  y_resampled_ros,
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.69      0.78      0.73        60
#    High blood pressure       0.41      0.30      0.35        30
#
#               accuracy                           0.62        90
#              macro avg       0.55      0.54      0.54        90
#           weighted avg       0.60      0.62      0.60        90
#
# Train set
# Random Forests roc-auc: 1.0
# Test set
# Random Forests roc-auc: 0.5705555555555555

# %% [markdown]
# ### LOGISTIC REGRESSION MODEL

# %%
def run_LogisticRegression(X_train, X_test, y_train, y_test):
    
    lr = LogisticRegression(random_state = 42)
    lr.fit(X_train, y_train)
    
    pred_lr = lr.predict(X_test)
    
    sns.reset_orig()

    ConfusionMatrixDisplay.from_predictions(
            y_test, pred_lr,
            labels = lr.classes_,
            cmap = 'magma'
    );
    
    
    
    print(classification_report(y_test, pred_lr, target_names = ['No High blood pressure', 'High blood pressure']))

    
    
    print('Train set')
    pred_lr = lr.predict_proba(X_train)
    print('Logistic Regression roc-auc: {}'.format(roc_auc_score(y_train, pred_lr[:,1])))
    
    print('Test set')
    pred_lr = lr.predict_proba(X_test)
    print('Logistic Regression roc-auc: {}'.format(roc_auc_score(y_test, pred_lr[:,1])))

# %% [markdown]
# ### Evaluate performance of algorithm built using imbalanced dataset

# %%
# evaluate performance of algorithm built using imbalanced dataset

run_LogisticRegression(X_train,
                      X_test,
                      y_train,
                      y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.70      0.88      0.78        60
#    High blood pressure       0.50      0.23      0.32        30
#
#               accuracy                           0.67        90
#              macro avg       0.60      0.56      0.55        90
#           weighted avg       0.63      0.67      0.63        90
#
# Train set
# Logistic Regression roc-auc: 0.6717412935323384
# Test set
# Logistic Regression roc-auc: 0.5716666666666667

# %% [markdown]
# ### Evaluate performance of algorithm built using Tomek Links

# %%
# evaluate performance of algorithm built using Tomek Links

run_LogisticRegression(X_resampled_t,
                      X_test,
                      y_resampled_t,
                      y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.71      0.73      0.72        60
#    High blood pressure       0.43      0.40      0.41        30
#
#               accuracy                           0.62        90
#              macro avg       0.57      0.57      0.57        90
#           weighted avg       0.62      0.62      0.62        90
#
# Train set
# Logistic Regression roc-auc: 0.6875840978593272
# Test set
# Logistic Regression roc-auc: 0.5705555555555556

# %% [markdown]
# ### Evaluate performance of algorithm built using Border line SMOTE

# %%
# evaluate performance of algorithm built using Border line SMOTE

run_LogisticRegression(X_resampled_b,
                      X_test,
                      y_resampled_b,
                      y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.67      0.55      0.61        60
#    High blood pressure       0.34      0.47      0.39        30
#
#               accuracy                           0.52        90
#              macro avg       0.51      0.51      0.50        90
#           weighted avg       0.56      0.52      0.54        90
#
# Train set
# Logistic Regression roc-auc: 0.679772777901537
# Test set
# Logistic Regression roc-auc: 0.5888888888888889

# %% [markdown]
# ### Evaluate performance of algorithm built using SMOTE

# %%
# evaluate performance of algorithm built using SMOTE

run_LogisticRegression(X_resampled_s,
                      X_test,
                      y_resampled_s,
                      y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.73      0.62      0.67        60
#    High blood pressure       0.41      0.53      0.46        30
#
#               accuracy                           0.59        90
#              macro avg       0.57      0.57      0.57        90
#           weighted avg       0.62      0.59      0.60        90
#
# Train set
# Logistic Regression roc-auc: 0.6869570060147026
# Test set
# Logistic Regression roc-auc: 0.5766666666666667

# %% [markdown]
# ### Evaluate performance of algorithm built using Random oversampler

# %%
# evaluate performance of algorithm built using Random oversampler

run_LogisticRegression(X_resampled_ros,
                  X_test,
                  y_resampled_ros,
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.69      0.52      0.59        60
#    High blood pressure       0.36      0.53      0.43        30
#
#               accuracy                           0.52        90
#              macro avg       0.52      0.53      0.51        90
#           weighted avg       0.58      0.52      0.54        90
#
# Train set
# Logistic Regression roc-auc: 0.6796057028291379
# Test set
# Logistic Regression roc-auc: 0.5716666666666667

# %% [markdown]
# ### IMPROVING THE MODEL USING Gridsearch FOR LOGISTIC REGRESSION MODEL

# %%
# Define the parameter grid
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100], 'penalty': ['l1', 'l2'], 'solver': ['liblinear', 'lbfgs']}

# %%
def grid_LogisticRegression(X_train, X_test, y_train, y_test):
    
    logreg_classifier = LogisticRegression(random_state = 42)
    
    grid_search = GridSearchCV(logreg_classifier, param_grid, cv=5)
    
    grid_search.fit(X_train, y_train)
    
    
    grid_predictions = grid_search.predict(X_test)
    
    sns.reset_orig()

    ConfusionMatrixDisplay.from_predictions(
            y_test, grid_predictions,
            labels = grid_search.classes_,
            cmap = 'magma'
    );
    
    
    
    print(classification_report(y_test, grid_predictions, target_names = ['No High blood pressure', 'High blood pressure']))
    
    
    
    print('Train set')
    grid_predictions = grid_search.predict_proba(X_train)
    print('Random Forests roc-auc: {}'.format(roc_auc_score(y_train, grid_predictions[:,1])))
    
    print('Test set')
    grid_predictions = grid_search.predict_proba(X_test)
    print('Random Forests roc-auc: {}'.format(roc_auc_score(y_test, grid_predictions[:,1])))

# %% [markdown]
# ### Evaluate performance of algorithm built using imbalanced dataset

# %%
# evaluate performance of algorithm built using imbalanced dataset

grid_LogisticRegression(X_train,
                      X_test,
                      y_train,
                      y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.67      1.00      0.80        60
#    High blood pressure       0.00      0.00      0.00        30
#
#               accuracy                           0.67        90
#              macro avg       0.33      0.50      0.40        90
#           weighted avg       0.44      0.67      0.53        90
#
# Train set
# Random Forests roc-auc: 0.5
# Test set
# Random Forests roc-auc: 0.5

# %% [markdown]
# ### Evaluate performance of algorithm built using Tomek Links

# %%
# evaluate performance of algorithm built using Tomek Links

grid_LogisticRegression(X_resampled_t,
                      X_test,
                      y_resampled_t,
                      y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.67      1.00      0.80        60
#    High blood pressure       0.00      0.00      0.00        30
#
#               accuracy                           0.67        90
#              macro avg       0.33      0.50      0.40        90
#           weighted avg       0.44      0.67      0.53        90
#
# Train set
# Random Forests roc-auc: 0.5
# Test set
# Random Forests roc-auc: 0.5

# %% [markdown]
# ### Evaluate performance of algorithm built using Border line SMOTE

# %%
# evaluate performance of algorithm built using Border line SMOTE

grid_LogisticRegression(X_resampled_b,
                      X_test,
                      y_resampled_b,
                      y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.75      0.55      0.63        60
#    High blood pressure       0.41      0.63      0.50        30
#
#               accuracy                           0.58        90
#              macro avg       0.58      0.59      0.57        90
#           weighted avg       0.64      0.58      0.59        90
#
# Train set
# Random Forests roc-auc: 0.6772666518155491
# Test set
# Random Forests roc-auc: 0.5983333333333334

# %% [markdown]
# ### Evaluate performance of algorithm built using SMOTE

# %%
grid_LogisticRegression(X_resampled_s,
                      X_test,
                      y_resampled_s,
                      y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.71      0.60      0.65        60
#    High blood pressure       0.38      0.50      0.43        30
#
#               accuracy                           0.57        90
#              macro avg       0.55      0.55      0.54        90
#           weighted avg       0.60      0.57      0.58        90
#
# Train set
# Random Forests roc-auc: 0.6865114724883048
# Test set
# Random Forests roc-auc: 0.5861111111111111

# %% [markdown]
# ### Evaluate performance of algorithm built using Random oversampler

# %%
# evaluate performance of algorithm built using Random oversampler

grid_LogisticRegression(X_resampled_ros,
                  X_test,
                  y_resampled_ros,
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.71      0.53      0.61        60
#    High blood pressure       0.38      0.57      0.45        30
#
#               accuracy                           0.54        90
#              macro avg       0.54      0.55      0.53        90
#           weighted avg       0.60      0.54      0.56        90
#
# Train set
# Random Forests roc-auc: 0.6556582757852528
# Test set
# Random Forests roc-auc: 0.5833333333333333

# %% [markdown]
# ### SUPPORT VECTOR MODEL

# %%
def run_SupportVector(X_train, X_test, y_train, y_test):
    
    sv = SVC(probability=True, random_state = 42)
    sv.fit(X_train, y_train)
    
    pred_sv = sv.predict(X_test)
    
    sns.reset_orig()

    ConfusionMatrixDisplay.from_predictions(
            y_test, pred_sv,
            labels = sv.classes_,
            cmap = 'magma'
    );
    
    
    
    print(classification_report(y_test, pred_sv, target_names = ['No High blood pressure', 'High blood pressure']))

    
    
    print('Train set')
    pred_sv = sv.predict_proba(X_train)
    print('Suport vector roc-auc: {}'.format(roc_auc_score(y_train,pred_sv[:,1])))
    
    print('Test set')
    pred_sv = sv.predict_proba(X_test)
    print('Suport vector roc-auc: {}'.format(roc_auc_score(y_test, pred_sv[:,1])))

# %% [markdown]
# ### Evaluate performance of algorithm built using imbalanced dataset

# %%
# evaluate performance of algorithm built using imbalanced dataset

run_SupportVector(X_train, 
                  X_test, 
                  y_train, 
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.65      0.90      0.76        60
#    High blood pressure       0.14      0.03      0.05        30
#
#               accuracy                           0.61        90
#              macro avg       0.40      0.47      0.40        90
#           weighted avg       0.48      0.61      0.52        90
#
# Train set
# Suport vector roc-auc: 0.9015920398009951
# Test set
# Suport vector roc-auc: 0.5766666666666668

# %% [markdown]
# ### Evaluate performance of algorithm built using Tomek Links

# %%
# evaluate performance of algorithm built using Tomek Links

run_SupportVector(X_resampled_t, 
                  X_test, 
                  y_resampled_t, 
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.70      0.72      0.71        60
#    High blood pressure       0.41      0.40      0.41        30
#
#               accuracy                           0.61        90
#              macro avg       0.56      0.56      0.56        90
#           weighted avg       0.61      0.61      0.61        90
#
# Train set
# Suport vector roc-auc: 0.9102140672782875
# Test set
# Suport vector roc-auc: 0.5777777777777778

# %% [markdown]
# ### Evaluate performance of algorithm built using Border line SMOTE

# %%
# evaluate performance of algorithm built using Border line SMOTE

run_SupportVector(X_resampled_b, 
                   X_test, 
                   y_resampled_b, 
                   y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.70      0.65      0.67        60
#    High blood pressure       0.38      0.43      0.41        30
#
#               accuracy                           0.58        90
#              macro avg       0.54      0.54      0.54        90
#           weighted avg       0.59      0.58      0.58        90
#
# Train set
# Suport vector roc-auc: 0.9149587881488082
# Test set
# Suport vector roc-auc: 0.5722222222222223

# %% [markdown]
# ### Evaluate performance of algorithm built using SMOTE

# %%
# evaluate performance of algorithm built using SMOTE

run_SupportVector(X_resampled_s,
                      X_test,
                      y_resampled_s,
                      y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.68      0.65      0.67        60
#    High blood pressure       0.36      0.40      0.38        30
#
#               accuracy                           0.57        90
#              macro avg       0.52      0.53      0.52        90
#           weighted avg       0.58      0.57      0.57        90
#
# Train set
# Suport vector roc-auc: 0.9132880374248162
# Test set
# Suport vector roc-auc: 0.5472222222222223

# %% [markdown]
# ### Evaluate performance of algorithm built using Random oversampler

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
# evaluate performance of algorithm built using Random oversampler

run_SupportVector(X_resampled_ros,
                  X_test,
                  y_resampled_ros,
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.73      0.63      0.68        60
#    High blood pressure       0.42      0.53      0.47        30
#
#               accuracy                           0.60        90
#              macro avg       0.58      0.58      0.57        90
#           weighted avg       0.63      0.60      0.61        90
#
# Train set
# Suport vector roc-auc: 0.9104199153486299
# Test set
# Suport vector roc-auc: 0.5544444444444445

# %% [markdown]
# ### IMPROVING THE MODEL USING Gridsearch FOR VECTOR SUPPORT MODEL

# %%
# Define the parameter grid
param_grid = {'C': [0.1, 1, 10, 100], 'gamma': [0.0001, 0.001, 0.01, 0.1, 1], 'kernel': ['linear', 'rbf']}

# %%
def grid_SupportVector(X_train, X_test, y_train, y_test):
    
    svm_classifier = SVC(probability=True,  random_state=42)
    
    grid_search = GridSearchCV(svm_classifier, param_grid, cv=5)
    
    grid_search.fit(X_train, y_train)
    
    
    grid_predictions = grid_search.predict(X_test)
    
    sns.reset_orig()

    ConfusionMatrixDisplay.from_predictions(
            y_test, grid_predictions,
            labels = grid_search.classes_,
            cmap = 'magma'
    );
    
    
    
    print(classification_report(y_test, grid_predictions, target_names = ['No High blood pressure', 'High blood pressure']))
    
    
    
    print('Train set')
    grid_predictions = grid_search.predict_proba(X_train)
    print('Suport vector roc-auc: {}'.format(roc_auc_score(y_train, grid_predictions[:,1])))
    
    print('Test set')
    grid_predictions = grid_search.predict_proba(X_test)
    print('Suport vector roc-auc: {}'.format(roc_auc_score(y_test, grid_predictions[:,1])))

# %% [markdown]
# ## Evaluate performance of algorithm built using imbalanced dataset

# %%
# evaluate performance of algorithm built using imbalanced dataset

grid_SupportVector(X_train, 
                  X_test, 
                  y_train, 
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.67      1.00      0.80        60
#    High blood pressure       0.00      0.00      0.00        30
#
#               accuracy                           0.67        90
#              macro avg       0.33      0.50      0.40        90
#           weighted avg       0.44      0.67      0.53        90
#
# Train set
# Suport vector roc-auc: 0.35442786069651744
# Test set
# Suport vector roc-auc: 0.46611111111111114

# %% [markdown]
# ### Evaluate performance of algorithm built using Tomek Links

# %%
# evaluate performance of algorithm built using Tomek Links

grid_SupportVector(X_resampled_t, 
                  X_test, 
                  y_resampled_t, 
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.65      0.65      0.65        60
#    High blood pressure       0.30      0.30      0.30        30
#
#               accuracy                           0.53        90
#              macro avg       0.47      0.47      0.47        90
#           weighted avg       0.53      0.53      0.53        90
#
# Train set
# Suport vector roc-auc: 0.9982874617737003
# Test set
# Suport vector roc-auc: 0.54

# %% [markdown]
# ### Evaluate performance of algorithm built using Border line SMOTE

# %%
# evaluate performance of algorithm built using Border line SMOTE

grid_SupportVector(X_resampled_b, 
                   X_test, 
                   y_resampled_b, 
                   y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.68      0.88      0.77        60
#    High blood pressure       0.42      0.17      0.24        30
#
#               accuracy                           0.64        90
#              macro avg       0.55      0.53      0.50        90
#           weighted avg       0.59      0.64      0.59        90
#
# Train set
# Suport vector roc-auc: 1.0
# Test set
# Suport vector roc-auc: 0.4927777777777777

# %% [markdown]
# ### Evaluate performance of algorithm built using SMOTE

# %%
# evaluate performance of algorithm built using SMOTE

grid_SupportVector(X_resampled_s,
                      X_test,
                      y_resampled_s,
                      y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.66      0.90      0.76        60
#    High blood pressure       0.25      0.07      0.11        30
#
#               accuracy                           0.62        90
#              macro avg       0.45      0.48      0.43        90
#           weighted avg       0.52      0.62      0.54        90
#
# Train set
# Suport vector roc-auc: 1.0
# Test set
# Suport vector roc-auc: 0.48055555555555557

# %% [markdown]
# ### Evaluate performance of algorithm built using Random oversampler

# %%
# evaluate performance of algorithm built using Random oversampler

grid_SupportVector(X_resampled_ros,
                  X_test,
                  y_resampled_ros,
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.67      0.97      0.79        60
#    High blood pressure       0.33      0.03      0.06        30
#
#               accuracy                           0.66        90
#              macro avg       0.50      0.50      0.42        90
#           weighted avg       0.56      0.66      0.55        90
#
# Train set
# Suport vector roc-auc: 1.0
# Test set
# Suport vector roc-auc: 0.49333333333333335

# %% [markdown]
# ## KNN MODEL

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
def run_KNN_Model(X_train, X_test, y_train, y_test):
    
    knn_model = KNeighborsClassifier(n_neighbors=3)
    
    knn_model.fit(X_train, y_train)
    
    pred_knn = knn_model.predict(X_test)
    
    sns.reset_orig()

    ConfusionMatrixDisplay.from_predictions(
            y_test, pred_knn,
            labels = knn_model.classes_,
            cmap = 'magma'
    );
    
    
    
    print(classification_report(y_test, pred_knn, target_names = ['No High blood pressure', 'High blood pressure']))

    
    
    print('Train set')
    pred_knn = knn_model.predict_proba(X_train)
    print('Suport vector roc-auc: {}'.format(roc_auc_score(y_train,pred_knn[:,1])))
    
    print('Test set')
    pred_knn = knn_model.predict_proba(X_test)
    print('Suport vector roc-auc: {}'.format(roc_auc_score(y_test, pred_knn[:,1])))

# %% [markdown]
# ### Evaluate performance of algorithm built using imbalanced dataset

# %%
# evaluate performance of algorithm built using imbalanced dataset

run_KNN_Model(X_train, 
                  X_test, 
                  y_train, 
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.64      0.63      0.64        60
#    High blood pressure       0.29      0.30      0.30        30
#
#               accuracy                           0.52        90
#              macro avg       0.47      0.47      0.47        90
#           weighted avg       0.53      0.52      0.52        90
#
# Train set
# Suport vector roc-auc: 0.7937810945273631
# Test set
# Suport vector roc-auc: 0.4905555555555555

# %% [markdown]
# ### Evaluate performance of algorithm built using Tomek Links

# %%
# evaluate performance of algorithm built using Tomek Links

run_KNN_Model(X_resampled_t, 
                  X_test, 
                  y_resampled_t, 
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.71      0.57      0.63        60
#    High blood pressure       0.38      0.53      0.44        30
#
#               accuracy                           0.56        90
#              macro avg       0.54      0.55      0.54        90
#           weighted avg       0.60      0.56      0.57        90
#
# Train set
# Suport vector roc-auc: 0.8338226299694189
# Test set
# Suport vector roc-auc: 0.5583333333333333

# %% [markdown]
# ### Evaluate performance of algorithm built using Border line SMOTE

# %%
# evaluate performance of algorithm built using Border line SMOTE

run_KNN_Model(X_resampled_b, 
                   X_test, 
                   y_resampled_b, 
                   y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.63      0.40      0.49        60
#    High blood pressure       0.31      0.53      0.39        30
#
#               accuracy                           0.44        90
#              macro avg       0.47      0.47      0.44        90
#           weighted avg       0.52      0.44      0.46        90
#
# Train set
# Suport vector roc-auc: 0.9171864557807975
# Test set
# Suport vector roc-auc: 0.5122222222222222

# %% [markdown]
# ### Evaluate performance of algorithm built using SMOTE

# %%
# evaluate performance of algorithm built using SMOTE

run_KNN_Model(X_resampled_s,
                      X_test,
                      y_resampled_s,
                      y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.64      0.47      0.54        60
#    High blood pressure       0.30      0.47      0.37        30
#
#               accuracy                           0.47        90
#              macro avg       0.47      0.47      0.45        90
#           weighted avg       0.53      0.47      0.48        90
#
# Train set
# Suport vector roc-auc: 0.9093339273780352
# Test set
# Suport vector roc-auc: 0.4777777777777778

# %% [markdown]
# ### Evaluate performance of algorithm built using Random oversampler

# %%
# evaluate performance of algorithm built using Random oversampler

run_KNN_Model(X_resampled_ros,
                  X_test,
                  y_resampled_ros,
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.70      0.55      0.62        60
#    High blood pressure       0.37      0.53      0.44        30
#
#               accuracy                           0.54        90
#              macro avg       0.54      0.54      0.53        90
#           weighted avg       0.59      0.54      0.56        90
#
# Train set
# Suport vector roc-auc: 0.8842169748273558
# Test set
# Suport vector roc-auc: 0.5425

# %% [markdown]
# ## IMPROVING KNN MODEL

# %%
param_grid = {'n_neighbors': [3, 5, 7, 9, 11]}

# %%
def grid_run_KNN_Model(X_train, X_test, y_train, y_test):
    
    knn_model = KNeighborsClassifier()
    
    grid_search = GridSearchCV( knn_model, param_grid, cv=5)
    
    grid_search.fit(X_train, y_train)
    
    
    grid_predictions = grid_search.predict(X_test)
    
    sns.reset_orig()

    ConfusionMatrixDisplay.from_predictions(
            y_test, grid_predictions,
            labels = grid_search.classes_,
            cmap = 'magma'
    );
    
    
    
    print(classification_report(y_test, grid_predictions, target_names = ['No High blood pressure', 'High blood pressure']))
    
    
    
    print('Train set')
    grid_predictions = grid_search.predict_proba(X_train)
    print('Suport vector roc-auc: {}'.format(roc_auc_score(y_train, grid_predictions[:,1])))
    
    print('Test set')
    grid_predictions = grid_search.predict_proba(X_test)
    print('Suport vector roc-auc: {}'.format(roc_auc_score(y_test, grid_predictions[:,1])))

# %% [markdown]
# ### Evaluate performance of algorithm built using imbalanced dataset

# %%
# evaluate performance of algorithm built using imbalanced dataset

grid_run_KNN_Model(X_train, 
                  X_test, 
                  y_train, 
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.68      0.78      0.73        60
#    High blood pressure       0.38      0.27      0.31        30
#
#               accuracy                           0.61        90
#              macro avg       0.53      0.53      0.52        90
#           weighted avg       0.58      0.61      0.59        90
#
# Train set
# Suport vector roc-auc: 0.7179601990049752
# Test set
# Suport vector roc-auc: 0.5372222222222222

# %% [markdown]
# ### Evaluate performance of algorithm built using Tomek Links

# %%
# evaluate performance of algorithm built using Tomek Links

grid_run_KNN_Model(X_resampled_t, 
                  X_test, 
                  y_resampled_t, 
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.71      0.57      0.63        60
#    High blood pressure       0.38      0.53      0.44        30
#
#               accuracy                           0.56        90
#              macro avg       0.54      0.55      0.54        90
#           weighted avg       0.60      0.56      0.57        90
#
# Train set
# Suport vector roc-auc: 0.8338226299694189
# Test set
# Suport vector roc-auc: 0.5583333333333333

# %% [markdown]
# ### Evaluate performance of algorithm built using Border line SMOTE

# %%
# evaluate performance of algorithm built using Border line SMOTE

grid_run_KNN_Model(X_resampled_b, 
                   X_test, 
                   y_resampled_b, 
                   y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.69      0.42      0.52        60
#    High blood pressure       0.35      0.63      0.45        30
#
#               accuracy                           0.49        90
#              macro avg       0.52      0.53      0.49        90
#           weighted avg       0.58      0.49      0.50        90
#
# Train set
# Suport vector roc-auc: 0.7942748941857875
# Test set
# Suport vector roc-auc: 0.595

# %% [markdown]
# ### Evaluate performance of algorithm built using SMOTE

# %%
# evaluate performance of algorithm built using SMOTE

grid_run_KNN_Model(X_resampled_s,
                      X_test,
                      y_resampled_s,
                      y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.71      0.42      0.53        60
#    High blood pressure       0.36      0.67      0.47        30
#
#               accuracy                           0.50        90
#              macro avg       0.54      0.54      0.50        90
#           weighted avg       0.60      0.50      0.51        90
#
# Train set
# Suport vector roc-auc: 0.7933838271329918
# Test set
# Suport vector roc-auc: 0.5344444444444444

# %% [markdown]
# ### Evaluate performance of algorithm built using Random oversampler

# %%
# evaluate performance of algorithm built using Random oversampler

grid_run_KNN_Model(X_resampled_ros,
                  X_test,
                  y_resampled_ros,
                  y_test)
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.71      0.48      0.57        60
#    High blood pressure       0.37      0.60      0.46        30
#
#               accuracy                           0.52        90
#              macro avg       0.54      0.54      0.51        90
#           weighted avg       0.59      0.52      0.53        90
#
# Train set
# Suport vector roc-auc: 0.746658498552016
# Test set
# Suport vector roc-auc: 0.5586111111111111

# %% [markdown]
# ### The Best Model

# %%
# Define the parameter grid
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100], 'penalty': ['l1', 'l2'], 'solver': ['liblinear', 'lbfgs']}

    
logreg_classifier = LogisticRegression(random_state = 42)

grid_search = GridSearchCV(logreg_classifier, param_grid, cv=5)

grid_search.fit(X_resampled_b, y_resampled_b)


grid_predictions = grid_search.predict(X_test)

sns.reset_orig()

ConfusionMatrixDisplay.from_predictions(
        y_test, grid_predictions,
        labels = grid_search.classes_,
        cmap = 'magma'
);



print(classification_report(y_test, grid_predictions, target_names = ['No High blood pressure', 'High blood pressure']))



print('Train set')
grid_predictions = grid_search.predict_proba(X_train)
print('Random Forests roc-auc: {}'.format(roc_auc_score(y_train, grid_predictions[:,1])))

print('Test set')
grid_predictions = grid_search.predict_proba(X_test)
print('Random Forests roc-auc: {}'.format(roc_auc_score(y_test, grid_predictions[:,1])))
# Out:
#                         precision    recall  f1-score   support
#
# No High blood pressure       0.75      0.55      0.63        60
#    High blood pressure       0.41      0.63      0.50        30
#
#               accuracy                           0.58        90
#              macro avg       0.58      0.59      0.57        90
#           weighted avg       0.64      0.58      0.59        90
#
# Train set
# Random Forests roc-auc: 0.6576119402985076
# Test set
# Random Forests roc-auc: 0.5983333333333334

# %%
import pickle
file = open('random_forest_model_hbp.pkl','wb')
pickle.dump(grid_search, file)
file.close()
